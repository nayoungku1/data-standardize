# %% [markdown]
# # PRISM DATA CHECK (Before any preprocessing)
# * check the perturbation name, ntc labeling, CRISPR type, var name and etc.

# %%
import scanpy as sc

# %%
DIR = "/mnt/nas2/projects/vcc-data/PRISM/Datasets/"

# %% [markdown]
# ### GSE210681
# * control label: `non-targeting`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: only CRISPRi
# * Double perturbation: X

# %%
GSE210681 = sc.read_h5ad(DIR+"GSE210681.h5ad", backed = "r")
GSE210681.obs.head()
# Out:
# /home/dev02/miniconda3/envs/prophet_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#                    perturbation_name        guide_sequence  n_guides  \
# AAACCCAAGAATCCCT-1           PYROXD1  GCGGCGGAGCAACGGGACTC         1
# AAACCCAAGACCATTC-1             EPHA2  GGGCGTTGGTGACGTCACGC         1
# AAACCCAAGACGATAT-1     non-targeting              No_Guide         1
# AAACCCAAGCAGATAT-1     non-targeting              No_Guide         1
# AAACCCAAGCCGCACT-1     non-targeting              No_Guide         1
#
#                                                 batch               organism  \
# AAACCCAAGAATCCCT-1  GSM6435418_scRNAseq_2kG_2PMDox2_3  Humans (Homo sapiens)
# AAACCCAAGACCATTC-1  GSM6435418_scRNAseq_2kG_2PMDox2_3  Humans (Homo sapiens)
# AAACCCAAGACGATAT-1  GSM6435418_scRNAseq_2kG_2PMDox2_3  Humans (Homo sapiens)
# ...

# %%
GSE210681[GSE210681.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# ['non-targeting']
# Categories (1, object): ['non-targeting']

# %%
GSE210681.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPRi    794783
# Name: count, dtype: int64

# %% [markdown]
# ### GSE221321
# * control label: `non-targeting`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: `CRISPRi` + `CRISPR KO`
# * Double perturbation: O

# %%
GSE221321 = sc.read_h5ad(DIR+"GSE221321.h5ad", backed = "r")
GSE221321.obs.head()
# Out:
# /home/dev02/miniconda3/envs/prophet_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#                     Total_RNA_count  Total_unique_genes 10X_channel  \
# AAACCCAAGAGTGACC-1           2413.0                1278    Normal_1
# AAACCCACACAGGATG-1           9174.0                2666    Normal_1
# AAACCCACACCTCTAC-1           3779.0                1864    Normal_1
# AAACCCACATTGCCGG-1           9882.0                2892    Normal_1
# AAACCCAGTCATCACA-1          10399.0                2514    Normal_1
#
#                     Percent_mitochondrial_reads  \
# AAACCCAAGAGTGACC-1                     5.719022
# AAACCCACACAGGATG-1                     5.646392
# AAACCCACACCTCTAC-1                     6.086266
# AAACCCACATTGCCGG-1                     4.604331
# AAACCCAGTCATCACA-1                     3.413790
#
# ...

# %%
GSE221321[GSE221321.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# ['non-targeting']
# Categories (1, object): ['non-targeting']

# %%
GSE221321.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPR KO    119656
# CRISPRi       90475
# Name: count, dtype: int64

# %% [markdown]
# ### GSE208240
# * control label: `control` at `obs.condition`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: `CRISPRi` ONLY
# * Double perturbation: O

# %%
GSE208240 = sc.read_h5ad(DIR+"GSE208240.h5ad", backed = "r")
GSE208240.obs.head()
# Out:
#                               perturbation_name condition  targeting  \
# barcode
# AAACCTGAGAAACCTA-1              BCKDK + EIF2AK3      test  Targeting
# AAACCTGAGAATTCCC-1      COG6 + SIGMAR1 + TMEM97      test  Targeting
# AAACCTGAGCCGATTT-1              EIF2AK2 + STK16      test  Targeting
# AAACCTGAGCGAGAAA-1  AP3B1 + CCZ1 + EIF3F + RBX1      test  Targeting
# AAACCTGAGGTGCTTT-1                        TRMT1      test  Targeting
#
#                                                        guide_identity  \
# barcode
# AAACCTGAGAAACCTA-1  BCKDK_+_31119819.23-P1P2_CR3-cs1;EIF2AK3_-_889...
# AAACCTGAGAATTCCC-1  COG6_-_40229866.23-P1P2_CR3-cs1;SIGMAR1_+_3463...
# AAACCTGAGCCGATTT-1  EIF2AK2_+_37384079.23-P1P2_CR1-cs1;STK16_+_220...
# AAACCTGAGCGAGAAA-1  AP3B1_-_77590427.23-P1P2_CR1-cs1;CCZ1_-_593859...
# AAACCTGAGGTGCTTT-1                   TRMT1_-_13227169.23-P1P2_CR3-cs1
#
#                     number_of_guides      organism              cell_type  \
# barcode
# ...

# %%
GSE208240.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPRi    73989
# Name: count, dtype: int64

# %%
GSE208240.obs.condition.value_counts()
# Out:
# condition
# test       59674
# control    14315
# Name: count, dtype: int64

# %%
GSE208240.obs.targeting.value_counts()
# Out:
# targeting
# Targeting        59674
# Non-targeting    14315
# Name: count, dtype: int64

# %%
GSE208240[GSE208240.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# ['BECN1 + EMC2 + GOLGA7 + KPNA2 + MBTPS2 + RAB7..., 'ACE2 + non-targeting', 'ASNA1 + BCL2L1 + CDK6 + CKM + COG6 + CTSB + E..., 'CNBP + VPS39 + non-targeting', 'non-targeting', ..., 'CDK6 + HDAC2 + STAT2 + TMPRSS2 + non-targeting', 'CNBP + MARK2 + non-targeting', 'IFITM1 + RIPK1 + non-targeting', 'CHEK2 + SKIV2L + TBKBP1 + non-targeting', 'BAX + CCZ1B + COG5 + non-targeting']
# Length: 5958
# Categories (5958, object): ['ACE2 + ADCK4 + ANPEP + ATG14 + BCL2 + BRD4 + ..., 'ACE2 + ADCK4 + ARF1 + CASP8 + CCZ1B + ERN1 + ..., 'ACE2 + ADCK4 + ARFRP1 + B3GALT6 + BRD4 + CNBP..., 'ACE2 + ADCK4 + ATF6 + BAX + BCL2L1 + CWC27 + ..., ..., 'ZCRB1 + non-targeting', 'ZDHHC5 + non-targeting', 'ZYG11B + non-targeting', 'non-targeting']

# %%
GSE208240[GSE208240.obs.condition == "control"].obs
# Out:
#                                                     perturbation_name  \
# barcode
# AAACCTGGTGATGTGG-1  BECN1 + EMC2 + GOLGA7 + KPNA2 + MBTPS2 + RAB7A...
# AAACGGGAGAATAGGG-1                               ACE2 + non-targeting
# AAACGGGAGTCACGCC-1  ASNA1 + BCL2L1 + CDK6 + CKM + COG6 + CTSB + EI...
# AAACGGGCACATCCAA-1                       CNBP + VPS39 + non-targeting
# AAACGGGCATCACGAT-1                                      non-targeting
# ...                                                               ...
# TTTGGTTGTCTCGTTC-8                                      non-targeting
# TTTGGTTGTGAGTATA-8                              RNF41 + non-targeting
# TTTGGTTTCACCCTCA-8                               PPIA + non-targeting
# TTTGTCAGTCTCTTTA-8                 BAX + CCZ1B + COG5 + non-targeting
# TTTGTCAGTTTGACAC-8     CDK6 + HDAC2 + STAT2 + TMPRSS2 + non-targeting
#
#                    condition      targeting  \
# barcode
# AAACCTGGTGATGTGG-1   control  Non-targeting
# ...

# %% [markdown]
# ### GSE150062
# * control label: `non-targeting`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: `CRISPRi` ONLY
# * Double perturbation: X

# %%
GSE150062 = sc.read_h5ad(DIR+"GSE150062.h5ad", backed="r")
GSE150062.obs.head()
# Out:
#                      orig.ident  nCount_RNA  nFeature_RNA  nCount_grna  \
# AAACGAATCAGACCGC-1_1     diff_1       22521          5346           69
# AAAGGGCCAGAGAATT-1_1     diff_1       15066          3902          426
# AAAGGGCCATGAGAAT-1_1     diff_1       20844          5095          670
# AAAGTCCCATGGCACC-1_1     diff_1       14015          4028          820
# AAAGTCCTCGAGTACT-1_1     diff_1       34393          6566          535
#
#                       nFeature_grna  sample condition  UMI_count   z_score  \
# AAACGAATCAGACCGC-1_1             19  diff_1      test         45  1.088537
# AAAGGGCCAGAGAATT-1_1             11  diff_1      test        407  1.269091
# AAAGGGCCATGAGAAT-1_1             16  diff_1      test        649  0.908249
# AAAGTCCCATGGCACC-1_1             13  diff_1      test        805  1.661506
# AAAGTCCTCGAGTACT-1_1             14  diff_1      test        518  0.757062
#
#                             guide  ... low_res_cluster  trajectory  library  \
# ...

# %%
GSE150062.obs.perturbation_name
# Out:
# AAACGAATCAGACCGC-1_1    LH02412
# AAAGGGCCAGAGAATT-1_1     IMMP1L
# AAAGGGCCATGAGAAT-1_1      PCGF2
# AAAGTCCCATGGCACC-1_1      WNT5B
# AAAGTCCTCGAGTACT-1_1     AMBRA1
#                          ...
# TTGATGGGTTCCAGGC-1_6      MED24
# TTGGGCGAGGCTGAAC-1_6       PAF1
# TTGTTTGCACTAGGCC-1_6    LH13772
# TTGTTTGTCGCCTTGT-1_6     IL17RD
# TTTATGCGTCTGATAC-1_6    LH04660
# Name: perturbation_name, Length: 78393, dtype: category
# Categories (241, object): ['AEBP2', 'AMBRA1', 'AMER1', 'APC', ..., 'ZMYM5', 'ZNF385A', 'ZNF551', 'non-targeting']

# %%
GSE150062.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPRi    78393
# Name: count, dtype: int64

# %%
GSE150062[GSE150062.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# ['non-targeting']
# Categories (1, object): ['non-targeting']

# %% [markdown]
# ### GSE261283
# * control label: `non-targeting`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: `CRISPRi` ONLY
# * Double perturbation: O

# %%
GSE261283 = sc.read_h5ad(DIR+"GSE261283.h5ad", backed="r")
GSE261283.obs.head()
# Out:
# /home/dev02/miniconda3/envs/prophet_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#                     Pool  n_genes_by_counts  pct_counts_mt  total_counts  \
# barcode
# AAACCCAAGAAGCGGG-1     0               5729       3.017132         19787
# AAACCCAAGCCTGAAG-8     6               8513       5.231251         54270
# AAACCCAAGCTTACGT-8     6               7215       2.489260         40735
# AAACCCAAGGATTTGA-1     0               4444       6.514528         15074
# AAACCCAAGGTACAAT-7     5               7309       2.860941         39113
#
#                     total_counts_mt  num_features              feature_call  \
# barcode
# AAACCCAAGAAGCGGG-1              597             1               rs1919873_4
# AAACCCAAGCCTGAAG-8             2839             2  rs57246313_1|rs2332323_5
# ...

# %%
GSE261283.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPRi    33038
# Name: count, dtype: int64

# %%
GSE261283[GSE261283.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# ['non-targeting']
# Categories (1, object): ['non-targeting']

# %% [markdown]
# ### GSE165291
# * control label: `control` at `obs.condition`
# * perturbation column: `perturbation_name` on `obs`
# * CRISPR type: `CRISPRi`, `CRISPRn`
# * Double perturbation: X

# %%
GSE165291 = sc.read_h5ad(DIR+"GSE165291.h5ad", backed="r")
GSE165291.obs.head()
# Out:
# /home/dev02/miniconda3/envs/prophet_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#                       guide_identity  read_count  UMI_count   coverage  \
# cell_barcode
# AAACCTGAGAACTCGG-3  TRAPPC11_pMH2062        1332         86  15.488372
# AAACCTGAGAAGAAGC-4     STAT2_pMH2128         337         46   7.326087
# AAACCTGAGAAGGCCT-2     STAT2_pMH2128        1162         72  16.138889
# AAACCTGAGACACGAC-3     CASP9_pMH2178        1427         97  14.711340
# AAACCTGAGAGAACAG-4      HCCS_pMH2186         397         48   8.270833
#
#                     gemgroup  good_coverage  number_of_cells sample  \
# cell_barcode
# AAACCTGAGAACTCGG-3         3           True                1   host
# AAACCTGAGAAGAAGC-4         4           True                1   host
# AAACCTGAGAAGGCCT-2         2           True                1   host
# ...

# %%
GSE165291.obs.condition.unique()
# Out:
# ['test', 'control']
# Categories (2, object): ['control', 'test']

# %%
GSE165291[GSE165291.obs.condition == 'control'].obs
# Out:
#                                     guide_identity  read_count  UMI_count  \
# cell_barcode
# AAACCTGGTTGGTAAA-1                               *           1          1
# AAAGCAAAGCTAACAA-2                               *           3          3
# AAAGTAGCACGCTTTC-3                               *           2          2
# AAAGTAGTCAAGCCTA-4                               *           2          2
# AAATGCCCAATGGACG-1                               *           4          3
# ...                                            ...         ...        ...
# TTTGTCAGTCCGCTGA-3                               *         597         20
# TTTGTCAGTCGGATCC-3     control_human_AAVS1_pMH2520        1015         46
# TTTGTCATCCACGAAT-3  control_HCMV_US11-US12_pMH2518        1320         46
# TTTGTCATCCATGCTC-4       control_human_H11_pMH2524        1008         29
# TTTGTCATCGTTACAG-1    control_HCMV_US6-US7_pMH2512         934         47
#
# ...

# %%
GSE165291.obs.perturbation_name.value_counts()
# Out:
# perturbation_name
# RBBP5       2791
# RGP1        2302
# SLC35B2     2203
# IFNAR2      2002
# HS6ST1      1996
#             ...
# CLYBL        374
# RBX1         368
# US9-US10     333
# AAVS1        314
# TIGRE        228
# Name: count, Length: 95, dtype: int64

# %%
GSE165291[GSE165291.obs.condition == "control"].obs.perturbation_name.unique()
# Out:
# [NaN, 'CLYBL', 'US11-US12', 'US6-US7', 'US3-US6', 'AAVS1', 'H11', 'TIGRE', 'US9-US10']
# Categories (8, object): ['AAVS1', 'CLYBL', 'H11', 'TIGRE', 'US3-US6', 'US6-US7', 'US9-US10', 'US11-US12']

# %%
unique_list = GSE165291[GSE165291.obs.condition == "control"].obs.perturbation_name.unique()
for l in unique_list:
    print(f"======={l}=======")
    print(GSE165291[GSE165291.obs.perturbation_name == l].obs.condition.unique())
# Out:
# =======nan=======
# [], Categories (0, object): []
# =======CLYBL=======
# ['control']
# Categories (1, object): ['control']
# =======US11-US12=======
# ['control']
# Categories (1, object): ['control']
# =======US6-US7=======
# ['control']
# Categories (1, object): ['control']
# =======US3-US6=======
# ['control']
# Categories (1, object): ['control']
# =======AAVS1=======
# ['control']
# Categories (1, object): ['control']
# =======H11=======
# ['control']
# Categories (1, object): ['control']
# =======TIGRE=======
# ['control']
# Categories (1, object): ['control']
# =======US9-US10=======
# ['control']
# Categories (1, object): ['control']

# %%
GSE165291.obs.crispr_type.value_counts()
# Out:
# crispr_type
# CRISPRn    55388
# CRISPRi    46282
# Name: count, dtype: int64
